# %%
from pandas import *

# %%
data = pandas.read_csv("/docgraph/ha1c_links.csv")
zippop = pandas.read_csv("/docgraph/2010CensusByZCTA.csv")

# %%
data
# Out:
#                npi        provider_type medicare_participation_indicator  \
# 0       1003083429  Clinical Laboratory                                Y
# 1       1003083429  Clinical Laboratory                                Y
# 2       1003083429  Clinical Laboratory                                Y
# 3       1003083429  Clinical Laboratory                                Y
# 4       1003083429  Clinical Laboratory                                Y
# 5       1003083429  Clinical Laboratory                                Y
# 6       1003112145  Clinical Laboratory                                Y
# 7       1003112145  Clinical Laboratory                                Y
# 8       1003112145  Clinical Laboratory                                Y
# 9       1003112145  Clinical Laboratory                                Y
# 10      1003112145  Clinical Laboratory                                Y
# 11      1003112145  Clinical Laboratory                                Y
# ...

# %%
states = data['state']

# %%
zips = data['zip']

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['load', 'info', 'save', 'datetime', 'unique']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
import matplotlib.pyplot as plt

# %%
from collections import Counter

# %%
c = Counter(zips)

# %%
codes, counts = zip(*c.most_common())

# %%
plt.bar(range(10), counts[:10], align='center')
plt.xticks(range(10), codes[:10], rotation=90);

# %%
c[77030]
# Out:
# 2068

# %%
zippop
# Out:
#        Zip Code ZCTA  2010 Census Population
# 0               1001                   16769
# 1               1002                   29049
# 2               1003                   10372
# 3               1005                    5079
# 4               1007                   14649
# 5               1008                    1263
# 6               1009                     741
# 7               1010                    3609
# 8               1011                    1370
# 9               1012                     661
# 10              1013                   23188
# 11              1020                   29668
# 12              1022                    2451
# 13              1026                     946
# 14              1027                   17660
# 15              1028                   15720
# 16              1029                     789
# 17              1030                   11669
# 18              1031                    1308
# 19              1032                     570
# ...

# %%
type(zippop)
# Out:
# pandas.core.frame.DataFrame
